# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
import string

# %%
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\misha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\misha\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\misha\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def preprocess(book):
    book = book.lower()
    book = book.translate(str.maketrans('', '', string.punctuation))
    words = word_tokenize(book)
    stop_words = set(stopwords.words('russian'))
    words = [word for word in words if word not in stop_words]
    lemmatizer = WordNetLemmatizer()
    words = [lemmatizer.lemmatize(word) for word in words]
    return words

# %%
with open("whitefang.txt", "r", encoding="utf-8") as file:
    whitefang = file.read()

preprocessed_wf = preprocess(whitefang)
preprocessed_wf
# Out:
# ['jack',
#  'london',
#  'white',
#  'fang',
#  'part',
#  'i',
#  'chapter',
#  'ithe',
#  'trail',
#  'of',
#  'the',
#  'meat',
#  'dark',
#  'spruce',
#  'forest',
#  'frowned',
#  'on',
#  'either',
#  'side',
#  'the',
#  'frozen',
#  'waterway',
#  'the',
#  'tree',
#  'had',
#  'been',
#  'stripped',
#  'by',
#  'a',
#  'recent',
#  'wind',
#  'of',
#  'their',
#  'white',
#  'covering',
#  'of',
#  'frost',
#  'and',
#  'they',
#  'seemed',
#  'to',
#  'lean',
#  'towards',
#  'each',
#  'other',
#  'black',
#  'and',
#  'ominous',
#  'in',
#  'the',
#  'fading',
#  'light',
#  'a',
#  'vast',
#  'silence',
#  'reigned',
#  'over',
#  'the',
#  'land',
#  'the',
#  'land',
#  'itself',
#  'wa',
#  'a',
#  'desolation',
#  'lifeless',
#  'without',
#  'movement',
#  'so',
#  'lone',
#  'and',
#  'cold',
#  'that',
#  'the',
#  'spirit',
#  'of',
#  'it',
#  'wa',
#  'not',
#  'even',
#  'that',
#  'of',
#  'sadness',
#  'there',
#  'wa',
#  'a',
#  'hint',
#  'in',
#  'it',
# ...

# %%
with open("mazymay.txt", "r", encoding="utf-8") as file:
    mazymay = file.read()

preprocessed_mm = preprocess(mazymay)
preprocessed_mm
# Out:
# ['walt',
#  'master',
#  'is',
#  'not',
#  'a',
#  'very',
#  'large',
#  'boy',
#  'but',
#  'there',
#  'is',
#  'manliness',
#  'in',
#  'his',
#  'makeup',
#  'and',
#  'he',
#  'himself',
#  'although',
#  'he',
#  'doe',
#  'not',
#  'know',
#  'a',
#  'great',
#  'deal',
#  'that',
#  'most',
#  'boy',
#  'know',
#  'know',
#  'much',
#  'that',
#  'other',
#  'boy',
#  'do',
#  'not',
#  'know',
#  'he',
#  'ha',
#  'never',
#  'seen',
#  'a',
#  'train',
#  'of',
#  'car',
#  'or',
#  'an',
#  'elevator',
#  'in',
#  'his',
#  'life',
#  'and',
#  'for',
#  'that',
#  'matter',
#  'he',
#  'ha',
#  'never',
#  'once',
#  'looked',
#  'upon',
#  'a',
#  'cornfield',
#  'a',
#  'plow',
#  'a',
#  'cow',
#  'or',
#  'even',
#  'a',
#  'chicken',
#  'he',
#  'ha',
#  'never',
#  'had',
#  'a',
#  'pair',
#  'of',
#  'shoe',
#  'on',
#  'his',
#  'foot',
#  'nor',
#  'gone',
#  'to',
#  'a',
#  'picnic',
#  'or',
#  'a',
#  'party',
#  'nor',
#  'talked',
#  'to',
#  'a',
# ...

# %%
with open("lilbaby.txt", "r", encoding="utf-8") as file:
    lilbaby = file.read()

preprocessed_lb = preprocess(lilbaby)
preprocessed_lb
# Out:
# ['the',
#  'little',
#  'lady',
#  'of',
#  'the',
#  'big',
#  'house',
#  'by',
#  'jack',
#  'london',
#  'chapter',
#  'i',
#  'he',
#  'awoke',
#  'in',
#  'the',
#  'dark',
#  'his',
#  'awakening',
#  'wa',
#  'simple',
#  'easy',
#  'without',
#  'movement',
#  'save',
#  'for',
#  'the',
#  'eye',
#  'that',
#  'opened',
#  'and',
#  'made',
#  'him',
#  'aware',
#  'of',
#  'darkness',
#  'unlike',
#  'most',
#  'who',
#  'must',
#  'feel',
#  'and',
#  'grope',
#  'and',
#  'listen',
#  'to',
#  'and',
#  'contact',
#  'with',
#  'the',
#  'world',
#  'about',
#  'them',
#  'he',
#  'knew',
#  'himself',
#  'on',
#  'the',
#  'moment',
#  'of',
#  'awakening',
#  'instantly',
#  'identifying',
#  'himself',
#  'in',
#  'time',
#  'and',
#  'place',
#  'and',
#  'personality',
#  'after',
#  'the',
#  'lapsed',
#  'hour',
#  'of',
#  'sleep',
#  'he',
#  'took',
#  'up',
#  'without',
#  'effort',
#  'the',
#  'interrupted',
#  'tale',
#  'of',
#  'his',
#  'day',
#  'he',
# ...

# %%
with open("ironheel.txt", "r", encoding="utf-8") as file:
    ironheel = file.read()

preprocessed_ih = preprocess(ironheel)
preprocessed_ih
# Out:
# ['the',
#  'iron',
#  'heel',
#  'by',
#  'jack',
#  'london',
#  'at',
#  'first',
#  'this',
#  'earth',
#  'a',
#  'stage',
#  'so',
#  'gloomed',
#  'with',
#  'woe',
#  'you',
#  'almost',
#  'sicken',
#  'at',
#  'the',
#  'shifting',
#  'of',
#  'the',
#  'scene',
#  'and',
#  'yet',
#  'be',
#  'patient',
#  'our',
#  'playwright',
#  'may',
#  'show',
#  'in',
#  'some',
#  'fifth',
#  'act',
#  'what',
#  'this',
#  'wild',
#  'drama',
#  'mean',
#  'foreword',
#  'it',
#  'can',
#  'not',
#  'be',
#  'said',
#  'that',
#  'the',
#  'everhard',
#  'manuscript',
#  'is',
#  'an',
#  'important',
#  'historical',
#  'document',
#  'to',
#  'the',
#  'historian',
#  'it',
#  'bristle',
#  'with',
#  'errorsnot',
#  'error',
#  'of',
#  'fact',
#  'but',
#  'error',
#  'of',
#  'interpretation',
#  'looking',
#  'back',
#  'across',
#  'the',
#  'seven',
#  'century',
#  'that',
#  'have',
#  'lapsed',
#  'since',
#  'avis',
#  'everhard',
#  'completed',
#  'her',
# ...

# %%
with open("heartsof3.txt", "r", encoding="utf-8") as file:
    heartsof3 = file.read()

preprocessed_ho3 = preprocess(heartsof3)
preprocessed_ho3
# Out:
# ['heart',
#  'of',
#  'three',
#  'by',
#  'jack',
#  'london',
#  'foreword',
#  'i',
#  'hope',
#  'the',
#  'reader',
#  'will',
#  'forgive',
#  'me',
#  'for',
#  'beginning',
#  'this',
#  'foreword',
#  'with',
#  'a',
#  'brag',
#  'in',
#  'truth',
#  'this',
#  'yarn',
#  'is',
#  'a',
#  'celebration',
#  'by',
#  'it',
#  'completion',
#  'i',
#  'celebrate',
#  'my',
#  'fortieth',
#  'birthday',
#  'my',
#  'fiftieth',
#  'book',
#  'my',
#  'sixteenth',
#  'year',
#  'in',
#  'the',
#  'writing',
#  'game',
#  'and',
#  'a',
#  'new',
#  'departure',
#  'heart',
#  'of',
#  'three',
#  'is',
#  'a',
#  'new',
#  'departure',
#  'i',
#  'have',
#  'certainly',
#  'never',
#  'done',
#  'anything',
#  'like',
#  'it',
#  'before',
#  'i',
#  'am',
#  'pretty',
#  'certain',
#  'never',
#  'to',
#  'do',
#  'anything',
#  'like',
#  'it',
#  'again',
#  'and',
#  'i',
#  'havent',
#  'the',
#  'least',
#  'bit',
#  'of',
#  'reticence',
#  'in',
#  'proclaiming',
# ...

# %%
with open("adventure.txt", "r", encoding="utf-8") as file:
    adv = file.read()

preprocessed_adv = preprocess(adv)
preprocessed_adv
# Out:
# ['chapter',
#  'i',
#  '—',
#  'something',
#  'to',
#  'be',
#  'done',
#  'he',
#  'wa',
#  'a',
#  'very',
#  'sick',
#  'white',
#  'man',
#  'he',
#  'rode',
#  'pickaback',
#  'on',
#  'a',
#  'woolly',
#  'headed',
#  'blackskinned',
#  'savage',
#  'the',
#  'lobe',
#  'of',
#  'whose',
#  'ear',
#  'had',
#  'been',
#  'pierced',
#  'and',
#  'stretched',
#  'until',
#  'one',
#  'had',
#  'torn',
#  'out',
#  'while',
#  'the',
#  'other',
#  'carried',
#  'a',
#  'circular',
#  'block',
#  'of',
#  'carved',
#  'wood',
#  'three',
#  'inch',
#  'in',
#  'diameter',
#  'the',
#  'torn',
#  'ear',
#  'had',
#  'been',
#  'pierced',
#  'again',
#  'but',
#  'this',
#  'time',
#  'not',
#  'so',
#  'ambitiously',
#  'for',
#  'the',
#  'hole',
#  'accommodated',
#  'no',
#  'more',
#  'than',
#  'a',
#  'short',
#  'clay',
#  'pipe',
#  'the',
#  'manhorse',
#  'wa',
#  'greasy',
#  'and',
#  'dirty',
#  'and',
#  'naked',
#  'save',
#  'for',
#  'an',
#  'exceedingly',
# ...
